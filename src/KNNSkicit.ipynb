# %%
# Implementasi dengan Algoritma KNN (scikit-learn)

# %%
import numpy as nm  
import matplotlib.pyplot as mtp  
import pandas as pd
dataset1 = pd.read_csv('data_train.csv')  
dataset2 = pd.read_csv('data_validation.csv')

# %%
import seaborn as sns
sns.scatterplot(x=dataset1['battery_power'],y=dataset1['clock_speed'], hue=dataset1['price_range'])
# Out:
# <Axes: xlabel='battery_power', ylabel='clock_speed'>

# %%
x_train = dataset1.iloc[:, :-1].values
x_test = dataset2.iloc[:, :-1].values
y_train = dataset1.iloc[:, 20].values
y_test = dataset2.iloc[:, 20].values

# %%
from sklearn.preprocessing import StandardScaler  
scaler = StandardScaler()
scaler.fit(x_train)

x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %%
from sklearn.neighbors import KNeighborsClassifier  
classifier= KNeighborsClassifier(n_neighbors = 668, weights="distance", p=1)
classifier.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=668, p=1, weights='distance')

# %%
y_pred = classifier.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy: {accuracy}")
print()
print(confusion_matrix(y_test, y_pred))
print()
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.745
#
# [[133   9   0   0]
#  [ 29  89  26   0]
#  [  0  41 105   9]
#  [  0   0  39 120]]
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.94      0.88       142
#            1       0.64      0.62      0.63       144
#            2       0.62      0.68      0.65       155
#            3       0.93      0.75      0.83       159
#
#     accuracy                           0.74       600
#    macro avg       0.75      0.75      0.75       600
# weighted avg       0.75      0.74      0.75       600

# %% [markdown]
# *****
